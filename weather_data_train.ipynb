# %%
# !pip install scikit-learn meteostat geopy matplotlib seaborn
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
HIDDEN_SIZE = 16
NUM_LAYERS = 1
LEARNING_RATE = 0.001
BATCH_SIZE = 1024
N_STEPS = 7
EARLY_STOPPING_PATIENCE = 20

TARGET_CITY = "Budapest"
MAX_RADIUS_KM = 2000
ONLY_CAPITALS = True
RELOAD_CITIES = False

CACHE_VERIFIED = "verified_coordinates.pkl"
CACHE_FAILED = "unresolvable_cities.pkl"
TARGET_COLUMN = "Budapest_tmax"

# %%
import os, time, pickle
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
from meteostat import Point, Daily
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
def load_and_filter_cities():
    df = pd.read_csv("worldcities.csv")
    target = df[df["city_ascii"] == TARGET_CITY]
    if target.empty:
        raise ValueError(f"A megadott célváros ({TARGET_CITY}) nem található az adatbázisban.")

    if ONLY_CAPITALS:
        df = df[df["capital"] == "primary"]

    df = df[df.apply(lambda row: geodesic((target.iloc[0]["lat"], target.iloc[0]["lng"]), (row["lat"], row["lng"])).km <= MAX_RADIUS_KM, axis=1)]

    if TARGET_CITY not in df["city_ascii"].values:
        df = pd.concat([df, target])

    return {row["city_ascii"]: (row["lat"], row["lng"]) for _, row in df.iterrows()}

city_coordinates = load_and_filter_cities()
print(f"{len(city_coordinates)} város kiválasztva {MAX_RADIUS_KM} km-en belül {TARGET_CITY} körül.")
print(" ->", ", ".join(sorted(city_coordinates.keys())))
# Out:
# 52 város kiválasztva 2000 km-en belül Budapest körül.
#  -> Algiers, Amsterdam, Andorra la Vella, Ankara, Athens, Belgrade, Berlin, Bern, Bratislava, Brussels, Bucharest, Budapest, Chisinau, Copenhagen, Douglas, Dublin, Helsinki, Kyiv, Ljubljana, London, Luxembourg, Madrid, Minsk, Monaco, Moscow, Nicosia, Oslo, Paris, Podgorica, Prague, Pristina, Riga, Rome, Saint Helier, Saint Peter Port, San Marino, Sarajevo, Skopje, Sofia, Stockholm, Tallinn, The Hague, Tirana, Tripoli, Tunis, Vaduz, Valletta, Vatican City, Vienna, Vilnius, Warsaw, Zagreb

# %%
def load_pickle_file(path, default):
    if os.path.exists(path):
        with open(path, "rb") as f:
            return pickle.load(f)
    return default


def save_pickle_file(path, data):
    with open(path, "wb") as f:
        pickle.dump(data, f)


def initialize_geolocator():
    return Nominatim(user_agent="weather_project")

# %%
def query_city_coordinates(geolocator, city_list, verified, unresolvable, reload=False):
    for city in city_list:
        if city in verified:
            continue
        if not reload and city in unresolvable:
            print(f"{city}: korábban nem található, most sem próbáljuk újra.")
            continue
        try:
            location = geolocator.geocode(f"{city}, Europe")
            if location:
                coords = (location.latitude, location.longitude)
                verified[city] = coords
                print(f"{city}: ({coords[0]:.4f}, {coords[1]:.4f})")
            else:
                print(f"{city}: Nem található.")
                unresolvable.add(city)
        except Exception as e:
            print(f"Hiba {city} lekérdezésekor: {e}")
            unresolvable.add(city)
        time.sleep(1)
    return verified, unresolvable

# %%
verified_coordinates = load_pickle_file(CACHE_VERIFIED, {})
if verified_coordinates:
    print(f"{len(verified_coordinates)} város koordinátája már korábban letöltve.")

unresolvable_cities = load_pickle_file(CACHE_FAILED, set()) if not RELOAD_CITIES else set()

geolocator = initialize_geolocator()
verified_coordinates, unresolvable_cities = query_city_coordinates(
    geolocator,
    city_coordinates.keys(),
    verified_coordinates,
    unresolvable_cities,
    reload=RELOAD_CITIES
)

save_pickle_file(CACHE_VERIFIED, verified_coordinates)
save_pickle_file(CACHE_FAILED, unresolvable_cities)

city_coordinates = verified_coordinates
# Out:
# Moscow: (55.9395, 37.5172)
# London: (51.5022, -0.1779)
# Paris: (48.8788, 2.3223)
# Madrid: (48.8788, 2.3223)
# Berlin: (48.8796, 2.3270)
# Athens: (32.3502, -90.1363)
# Kyiv: (48.8655, 2.3151)
# Rome: (48.8823, 2.3213)
# Bucharest: (44.4759, 25.8142)
# Budapest: (48.8769, 2.3268)
# Amsterdam: (48.8809, 2.3271)
# Sofia: (42.7117, 23.4349)
# Prague: (48.5175, -2.7433)
# Brussels: (50.8455, 4.3570)
# Stockholm: (48.8771, 2.3225)
# Dublin: (48.8807, 2.3248)
# Skopje: (41.9934, 21.4250)
# Tirana: (41.3302, 19.8321)
# Sarajevo: (48.4559, -2.0609)
# Bern: (47.1260, 7.2400)
# Luxembourg: (47.4244, 0.6974)
# Andorra la Vella: (42.5089, 1.5312)

# %%
def ensure_data_directory(path="data"):
    os.makedirs(path, exist_ok=True)

def load_existing_weather_data(file_path, start, end):
    if not os.path.exists(file_path):
        return None, False

    try:
        data = pd.read_csv(file_path, parse_dates=["time"], index_col="time")
        if not data.empty:
            min_date, max_date = data.index.min(), data.index.max()
            if min_date <= start and max_date >= end:
                print(f"{os.path.basename(file_path)}: meglévő adat teljes időtartományban.")
                return data, True
            else:
                print(f"{os.path.basename(file_path)}: adat hiányos ({min_date.date()} – {max_date.date()}).")
    except Exception as e:
        print(f"{os.path.basename(file_path)}: hiba a fájl beolvasásakor – új letöltés szükséges. ({e})")

    return None, False

def download_weather_data(name, lat, lon, start, end, file_path):
    try:
        point = Point(lat, lon)
        data = Daily(point, start, end).fetch()
        data = data[["tavg", "tmin", "tmax", "prcp", "wspd"]]
        data.to_csv(file_path)
        print(f"{name}: adat letöltve és mentve.")
        return data
    except Exception as e:
        print(f"{name} adatainak lekérése sikertelen: {e}")
        return None

def validate_time_range(data, start, end, name):
    if data is None or data.empty:
        return False
    if data.index.min() > start or data.index.max() < end:
        print(f"{name}: kihagyva, mert nem teljes az időtartomány "
              f"({data.index.min().date()} – {data.index.max().date()})")
        return False
    return True

# %%
start = datetime(2000, 1, 1)
end = datetime(2024, 12, 31)

ensure_data_directory("data")
all_data = {}

for name, (lat, lon) in city_coordinates.items():
    file_path = f"data/{name}.csv"

    data, valid = load_existing_weather_data(file_path, start, end)

    # Ha nincs érvényes adat, töltsük le
    if not valid:
        data = download_weather_data(name, lat, lon, start, end, file_path)

    if not validate_time_range(data, start, end, name):
        continue

    data.columns = [f"{name}_{col}" for col in data.columns]
    all_data[name] = data

df = pd.concat(all_data.values(), axis=1, join="inner")
df.reset_index(inplace=True)
df.to_csv("european_capitals_weather_combined.csv", index=False)

df.head()
# Out:
# Moscow.csv: meglévő adat teljes időtartományban.
# London.csv: meglévő adat teljes időtartományban.
# Paris.csv: meglévő adat teljes időtartományban.
# Madrid.csv: meglévő adat teljes időtartományban.
# Berlin.csv: meglévő adat teljes időtartományban.
# Athens.csv: meglévő adat teljes időtartományban.
# Kyiv.csv: meglévő adat teljes időtartományban.
# Rome.csv: meglévő adat teljes időtartományban.
# Bucharest.csv: meglévő adat teljes időtartományban.
# Budapest.csv: meglévő adat teljes időtartományban.
# Amsterdam.csv: meglévő adat teljes időtartományban.
# Sofia.csv: meglévő adat teljes időtartományban.
# Prague.csv: meglévő adat teljes időtartományban.
# Brussels.csv: meglévő adat teljes időtartományban.
# Stockholm.csv: meglévő adat teljes időtartományban.
# Dublin.csv: meglévő adat teljes időtartományban.
# Skopje.csv: meglévő adat teljes időtartományban.
# Tirana.csv: adat hiányos (2000-01-02 – 2024-12-31).
# Tirana: adat letöltve és mentve.
# Tirana: kihagyva, mert nem teljes az időtartomány (2000-01-02 – 2024-12-31)
# Sarajevo.csv: meglévő adat teljes időtartományban.
# Bern.csv: adat hiányos (2010-11-27 – 2024-12-31).
# Bern: adat letöltve és mentve.
# Bern: kihagyva, mert nem teljes az időtartomány (2010-11-27 – 2024-12-31)
# Luxembourg.csv: meglévő adat teljes időtartományban.
# Andorra la Vella.csv: adat hiányos (2021-01-02 – 2024-12-31).
# Andorra la Vella: adat letöltve és mentve.
# Andorra la Vella: kihagyva, mert nem teljes az időtartomány (2021-01-02 – 2024-12-31)
#         time  Moscow_tavg  Moscow_tmin  Moscow_tmax  Moscow_prcp  Moscow_wspd  \
# 0 2000-01-01         -4.4         -4.9         -3.6          1.5          NaN
# 1 2000-01-02         -7.7         -9.0         -7.0          0.3          NaN
# 2 2000-01-03         -9.3        -11.0         -9.0          0.2          NaN
# 3 2000-01-04         -6.1         -9.1         -2.3          2.5          NaN
# 4 2000-01-05          0.1         -2.4          1.4          2.5          NaN
#
#    London_tavg  London_tmin  London_tmax  London_prcp  ...  Sarajevo_tavg  \
# 0          9.5          8.9         10.3          1.8  ...            9.8
# 1          9.5          8.0         11.0          NaN  ...            NaN
# 2          9.4          5.6         11.2          2.0  ...            NaN
# 3          6.3          5.0          9.4          3.8  ...           10.7
# 4          8.1          4.6         11.1          NaN  ...            NaN
#
#    Sarajevo_tmin  Sarajevo_tmax  Sarajevo_prcp  Sarajevo_wspd  \
# 0            8.6           11.0            NaN           11.4
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            6.6           12.5            NaN           21.3
# 4            NaN            NaN            NaN            NaN
#
#    Luxembourg_tavg  Luxembourg_tmin  Luxembourg_tmax  Luxembourg_prcp  \
# 0              8.2              7.2              9.8              0.5
# 1              8.2              6.6              9.2              0.0
# 2              7.8              6.6              9.6              1.5
# 3              8.4              6.4             10.8              0.0
# 4              7.6              5.9             10.8              4.3
#
#    Luxembourg_wspd
# 0              6.7
# 1              7.4
# 2             11.4
# 3             19.1
# 4             12.5
#
# [5 rows x 96 columns]

# %%
class WeatherDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
raw_features = df.drop(columns=["time"])

scaler = StandardScaler()
scaled_features = pd.DataFrame(scaler.fit_transform(raw_features), columns=raw_features.columns)

cleaned_features = scaled_features.dropna(axis=1)

features = cleaned_features.values

print("Maradt oszlop:", features.shape[1])

target_series = df[TARGET_COLUMN].values[N_STEPS:]

if TARGET_COLUMN not in df.columns:
    raise ValueError(f"A megadott célváltozó ({TARGET_COLUMN}) nem található a DataFrame-ben!")

target_series = df[TARGET_COLUMN].values


X = []
y = []

for i in range(N_STEPS, len(features)):
    X.append(features[i - N_STEPS:i])
    y.append(target_series[i])

X = np.array(X)
y = np.array(y)

# Belefutottunk NaN értékekbe tanulítás során ezért megvizsgáljuk az adatokat
print("Y statisztika:")
print("\tY NaN:", np.isnan(y).any())
print("\tY Inf:", np.isinf(y).any())
print("\tY max:", np.max(y))
print("\tY min:", np.min(y))
print(f"\tSzórás: {np.std(y):.4f}")
print(f"\tÁtlag: {np.mean(y):.4f}")

print("X statisztika:")
print("\tX NaN:", np.isnan(X).any())
print("\tX Inf:", np.isinf(X).any())
print("\tX max:", np.max(X))
print("\tX min:", np.min(X))
print(f"\tSzórás: {np.std(X):.4f}")
print(f"\tÁtlag: {np.mean(X):.4f}")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

train_dataset = WeatherDataset(X_train, y_train)
test_dataset = WeatherDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Maradt oszlop: 48
# Y statisztika:
# 	Y NaN: False
# 	Y Inf: False
# 	Y max: 42.6
# 	Y min: -5.1
# 	Szórás: 7.7506
# 	Átlag: 16.9958
# X statisztika:
# 	X NaN: False
# 	X Inf: False
# 	X max: 22.919412775789798
# 	X min: -3.722916988155856
# 	Szórás: 1.0000
# 	Átlag: 0.0007

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=1):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.fc(out)
        return out

# %%
class EarlyStopping:
    def __init__(self, patience=EARLY_STOPPING_PATIENCE, verbose=True, delta=1e-4):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_loss = float('inf')
        self.early_stop = False
        self.delta = delta

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping: {self.counter}/{self.patience} epoch óta nincs javulás.", end=' ')
            if self.counter >= self.patience:
                self.early_stop = True

# %%
print("CUDA elérhető:", torch.cuda.is_available())
print("CUDA verzió:", torch.version.cuda)
print("PyTorch build CUDA-támogatással:", torch.backends.cudnn.enabled)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Alapértelmezett eszköz:", device)
# Out:
# CUDA elérhető: True
# CUDA verzió: 12.1
# PyTorch build CUDA-támogatással: True
# Alapértelmezett eszköz: cuda

# %%
model = LSTMModel(input_size=X.shape[2], hidden_size=HIDDEN_SIZE, num_layers=NUM_LAYERS).to(device)

criterion = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
early_stopping = EarlyStopping(patience=EARLY_STOPPING_PATIENCE)
epoch = 0
train_loss_history = []
start_time = time.time()


while epoch < 10000:
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = model(inputs)
        loss = criterion(outputs, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)

    train_loss /= len(train_loader.dataset)
    print(f"\nEpoch {epoch+1}, Loss: {train_loss:.4f}", end=' ')
    train_loss_history.append(train_loss)


    early_stopping(train_loss)
    if early_stopping.early_stop:
        print("Korai leállítás aktiválva.")
        break

    epoch += 1

end_time = time.time()
elapsed_time = end_time - start_time
# Out:
# Epoch 1, Loss: 334.5886
# Epoch 2, Loss: 327.5321
# Epoch 3, Loss: 320.6833
# Epoch 4, Loss: 313.8816
# Epoch 5, Loss: 307.2591
# Epoch 6, Loss: 300.8965
# Epoch 7, Loss: 294.9156
# Epoch 8, Loss: 289.2744
# Epoch 9, Loss: 283.8794
# Epoch 10, Loss: 278.6654
# Epoch 11, Loss: 273.6134
# Epoch 12, Loss: 268.6522
# Epoch 13, Loss: 263.6391
# Epoch 14, Loss: 258.3947
# Epoch 15, Loss: 253.0493
# Epoch 16, Loss: 247.8649
# Epoch 17, Loss: 242.7908
# Epoch 18, Loss: 237.6523
# Epoch 19, Loss: 232.2918
# Epoch 20, Loss: 226.6325
# Epoch 21, Loss: 220.5057
# Epoch 22, Loss: 213.9408
# Epoch 23, Loss: 206.9241
# Epoch 24, Loss: 199.3102
# Epoch 25, Loss: 191.3214
# Epoch 26, Loss: 184.0507
# Epoch 27, Loss: 178.2128
# Epoch 28, Loss: 173.2093
# Epoch 29, Loss: 168.6187
# Epoch 30, Loss: 164.3952
# Epoch 31, Loss: 160.5328
# Epoch 32, Loss: 157.0242
# Epoch 33, Loss: 153.8147
# Epoch 34, Loss: 150.8104
# Epoch 35, Loss: 147.9466
# Epoch 36, Loss: 145.2103
# Epoch 37, Loss: 142.5456
# Epoch 38, Loss: 139.9684
# Epoch 39, Loss: 137.4587
# Epoch 40, Loss: 135.0064
# Epoch 41, Loss: 132.5957
# Epoch 42, Loss: 130.2302
# Epoch 43, Loss: 127.9537
# Epoch 44, Loss: 125.7208
# Epoch 45, Loss: 123.5539
# Epoch 46, Loss: 121.4310
# Epoch 47, Loss: 119.3618
# Epoch 48, Loss: 117.3253
# Epoch 49, Loss: 115.3403
# Epoch 50, Loss: 113.4093
# Epoch 51, Loss: 111.5172
# Epoch 52, Loss: 109.6663
# Epoch 53, Loss: 107.8420
# Epoch 54, Loss: 106.0632
# Epoch 55, Loss: 104.3323
# Epoch 56, Loss: 102.6362
# Epoch 57, Loss: 100.9775
# Epoch 58, Loss: 99.3439
# Epoch 59, Loss: 97.7383
# Epoch 60, Loss: 96.1713
# Epoch 61, Loss: 94.6324
# Epoch 62, Loss: 93.1171
# Epoch 63, Loss: 91.6455
# Epoch 64, Loss: 90.1853
# Epoch 65, Loss: 88.7549
# Epoch 66, Loss: 87.3531
# Epoch 67, Loss: 85.9989
# Epoch 68, Loss: 84.6811
# Epoch 69, Loss: 83.3612
# Epoch 70, Loss: 82.0832
# Epoch 71, Loss: 80.8118
# Epoch 72, Loss: 79.5715
# Epoch 73, Loss: 78.3405
# Epoch 74, Loss: 77.1464
# Epoch 75, Loss: 75.9635
# Epoch 76, Loss: 74.8229
# Epoch 77, Loss: 73.6800
# Epoch 78, Loss: 72.5657
# Epoch 79, Loss: 71.4590
# Epoch 80, Loss: 70.4026
# Epoch 81, Loss: 69.3408
# Epoch 82, Loss: 68.3140
# Epoch 83, Loss: 67.2927
# Epoch 84, Loss: 66.2912
# Epoch 85, Loss: 65.3192
# Epoch 86, Loss: 64.3600
# Epoch 87, Loss: 63.4148
# Epoch 88, Loss: 62.4858
# Epoch 89, Loss: 61.5815
# Epoch 90, Loss: 60.6868
# Epoch 91, Loss: 59.7993
# Epoch 92, Loss: 58.9386
# Epoch 93, Loss: 58.0745
# Epoch 94, Loss: 57.2358
# Epoch 95, Loss: 56.4095
# Epoch 96, Loss: 55.5959
# Epoch 97, Loss: 54.8026
# Epoch 98, Loss: 54.0194
# Epoch 99, Loss: 53.2552
# Epoch 100, Loss: 52.5028
# Epoch 101, Loss: 51.7571
# Epoch 102, Loss: 51.0252
# Epoch 103, Loss: 50.3046
# Epoch 104, Loss: 49.5976
# Epoch 105, Loss: 48.9021
# Epoch 106, Loss: 48.2276
# Epoch 107, Loss: 47.5614
# Epoch 108, Loss: 46.9132
# Epoch 109, Loss: 46.2633
# Epoch 110, Loss: 45.6181
# Epoch 111, Loss: 45.0011
# Epoch 112, Loss: 44.3832
# Epoch 113, Loss: 43.7718
# Epoch 114, Loss: 43.1869
# Epoch 115, Loss: 42.6067
# Epoch 116, Loss: 42.0262
# Epoch 117, Loss: 41.4523
# Epoch 118, Loss: 40.8942
# Epoch 119, Loss: 40.3425
# Epoch 120, Loss: 39.8131
# Epoch 121, Loss: 39.2860
# Epoch 122, Loss: 38.7668
# Epoch 123, Loss: 38.2586
# Epoch 124, Loss: 37.7534
# Epoch 125, Loss: 37.2596
# Epoch 126, Loss: 36.7904
# Epoch 127, Loss: 36.3008
# Epoch 128, Loss: 35.8340
# Epoch 129, Loss: 35.3777
# Epoch 130, Loss: 34.9234
# Epoch 131, Loss: 34.4650
# Epoch 132, Loss: 34.0353
# Epoch 133, Loss: 33.6010
# Epoch 134, Loss: 33.1768
# Epoch 135, Loss: 32.7648
# Epoch 136, Loss: 32.3479
# Epoch 137, Loss: 31.9456
# Epoch 138, Loss: 31.5568
# Epoch 139, Loss: 31.1612
# Epoch 140, Loss: 30.7722
# Epoch 141, Loss: 30.4036
# Epoch 142, Loss: 30.0576
# Epoch 143, Loss: 29.7028
# Epoch 144, Loss: 29.3391
# Epoch 145, Loss: 28.9724
# Epoch 146, Loss: 28.6207
# Epoch 147, Loss: 28.2805
# Epoch 148, Loss: 27.9412
# Epoch 149, Loss: 27.6113
# Epoch 150, Loss: 27.2928
# Epoch 151, Loss: 26.9731
# Epoch 152, Loss: 26.6718
# Epoch 153, Loss: 26.3714
# Epoch 154, Loss: 26.0749
# Epoch 155, Loss: 25.7709
# Epoch 156, Loss: 25.4834
# Epoch 157, Loss: 25.2112
# Epoch 158, Loss: 24.9190
# Epoch 159, Loss: 24.6376
# Epoch 160, Loss: 24.3641
# Epoch 161, Loss: 24.1052
# Epoch 162, Loss: 23.8534
# Epoch 163, Loss: 23.6062
# Epoch 164, Loss: 23.3359
# Epoch 165, Loss: 23.0911
# Epoch 166, Loss: 22.8445
# Epoch 167, Loss: 22.6119
# Epoch 168, Loss: 22.3608
# Epoch 169, Loss: 22.1432
# Epoch 170, Loss: 21.9210
# Epoch 171, Loss: 21.6851
# Epoch 172, Loss: 21.4585
# Epoch 173, Loss: 21.2340
# Epoch 174, Loss: 21.0209
# Epoch 175, Loss: 20.8072
# Epoch 176, Loss: 20.5974
# Epoch 177, Loss: 20.3896
# Epoch 178, Loss: 20.1882
# Epoch 179, Loss: 19.9872
# Epoch 180, Loss: 19.7864
# Epoch 181, Loss: 19.5973
# Epoch 182, Loss: 19.4011
# Epoch 183, Loss: 19.2197
# Epoch 184, Loss: 19.0295
# Epoch 185, Loss: 18.8527
# Epoch 186, Loss: 18.6796
# Epoch 187, Loss: 18.4987
# Epoch 188, Loss: 18.3348
# Epoch 189, Loss: 18.1623
# Epoch 190, Loss: 18.0043
# Epoch 191, Loss: 17.8386
# Epoch 192, Loss: 17.6874
# Epoch 193, Loss: 17.5197
# Epoch 194, Loss: 17.3545
# Epoch 195, Loss: 17.2062
# Epoch 196, Loss: 17.0801
# Epoch 197, Loss: 16.9249
# Epoch 198, Loss: 16.7685
# Epoch 199, Loss: 16.6105
# Epoch 200, Loss: 16.4655
# Epoch 201, Loss: 16.3307
# Epoch 202, Loss: 16.1947
# Epoch 203, Loss: 16.0682
# Epoch 204, Loss: 15.9460
# Epoch 205, Loss: 15.7978
# Epoch 206, Loss: 15.6641
# Epoch 207, Loss: 15.5338
# Epoch 208, Loss: 15.4054
# Epoch 209, Loss: 15.2793
# Epoch 210, Loss: 15.1550
# Epoch 211, Loss: 15.0399
# Epoch 212, Loss: 14.9242
# Epoch 213, Loss: 14.8057
# Epoch 214, Loss: 14.6821
# Epoch 215, Loss: 14.5739
# Epoch 216, Loss: 14.4658
# Epoch 217, Loss: 14.3509
# Epoch 218, Loss: 14.2348
# Epoch 219, Loss: 14.1273
# Epoch 220, Loss: 14.0340
# Epoch 221, Loss: 13.9286
# Epoch 222, Loss: 13.8127
# Epoch 223, Loss: 13.7107
# Epoch 224, Loss: 13.6081
# Epoch 225, Loss: 13.5142
# Epoch 226, Loss: 13.4162
# Epoch 227, Loss: 13.3356
# Epoch 228, Loss: 13.2389
# Epoch 229, Loss: 13.1545
# Epoch 230, Loss: 13.0525
# Epoch 231, Loss: 12.9629
# Epoch 232, Loss: 12.8741
# Epoch 233, Loss: 12.7733
# Epoch 234, Loss: 12.6857
# Epoch 235, Loss: 12.6020
# Epoch 236, Loss: 12.5295
# Epoch 237, Loss: 12.4336
# Epoch 238, Loss: 12.3526
# Epoch 239, Loss: 12.2700
# Epoch 240, Loss: 12.1851
# Epoch 241, Loss: 12.1174
# Epoch 242, Loss: 12.0383
# Epoch 243, Loss: 11.9493
# Epoch 244, Loss: 11.8797
# Epoch 245, Loss: 11.7974
# Epoch 246, Loss: 11.7255
# Epoch 247, Loss: 11.6485
# Epoch 248, Loss: 11.5743
# Epoch 249, Loss: 11.4995
# Epoch 250, Loss: 11.4290
# Epoch 251, Loss: 11.3579
# Epoch 252, Loss: 11.2903
# Epoch 253, Loss: 11.2242
# Epoch 254, Loss: 11.1607
# Epoch 255, Loss: 11.0953
# Epoch 256, Loss: 11.0279
# Epoch 257, Loss: 10.9840
# Epoch 258, Loss: 10.9349
# Epoch 259, Loss: 10.8578
# Epoch 260, Loss: 10.7801
# Epoch 261, Loss: 10.7211
# Epoch 262, Loss: 10.6804
# Epoch 263, Loss: 10.6129
# Epoch 264, Loss: 10.5599
# Epoch 265, Loss: 10.4836
# Epoch 266, Loss: 10.4183
# Epoch 267, Loss: 10.3589
# Epoch 268, Loss: 10.3026
# Epoch 269, Loss: 10.2459
# Epoch 270, Loss: 10.1954
# Epoch 271, Loss: 10.1437
# Epoch 272, Loss: 10.1045
# Epoch 273, Loss: 10.0396
# Epoch 274, Loss: 9.9807
# Epoch 275, Loss: 9.9407
# Epoch 276, Loss: 9.8811
# Epoch 277, Loss: 9.8340
# Epoch 278, Loss: 9.7897
# Epoch 279, Loss: 9.7336
# Epoch 280, Loss: 9.6864
# Epoch 281, Loss: 9.6330
# Epoch 282, Loss: 9.5941
# Epoch 283, Loss: 9.5467
# Epoch 284, Loss: 9.5035
# Epoch 285, Loss: 9.4681
# Epoch 286, Loss: 9.4154
# Epoch 287, Loss: 9.3736
# Epoch 288, Loss: 9.3280
# Epoch 289, Loss: 9.2927
# Epoch 290, Loss: 9.2308
# Epoch 291, Loss: 9.2103
# Epoch 292, Loss: 9.1510
# Epoch 293, Loss: 9.1172
# Epoch 294, Loss: 9.0683
# Epoch 295, Loss: 9.0351
# Epoch 296, Loss: 8.9813
# Epoch 297, Loss: 8.9491
# Epoch 298, Loss: 8.8976
# Epoch 299, Loss: 8.8619
# Epoch 300, Loss: 8.8173
# Epoch 301, Loss: 8.7792
# Epoch 302, Loss: 8.7407
# Epoch 303, Loss: 8.7086
# Epoch 304, Loss: 8.6678
# Epoch 305, Loss: 8.6308
# Epoch 306, Loss: 8.5960
# Epoch 307, Loss: 8.5879
# Epoch 308, Loss: 8.5499
# Epoch 309, Loss: 8.4977
# Epoch 310, Loss: 8.4660
# Epoch 311, Loss: 8.4302
# Epoch 312, Loss: 8.3899
# Epoch 313, Loss: 8.3601
# Epoch 314, Loss: 8.3322
# Epoch 315, Loss: 8.2987
# Epoch 316, Loss: 8.2684
# Epoch 317, Loss: 8.2492
# Epoch 318, Loss: 8.2197
# Epoch 319, Loss: 8.1753
# Epoch 320, Loss: 8.1439
# Epoch 321, Loss: 8.1129
# Epoch 322, Loss: 8.0791
# Epoch 323, Loss: 8.0495
# Epoch 324, Loss: 8.0157
# Epoch 325, Loss: 7.9944
# Epoch 326, Loss: 7.9611
# Epoch 327, Loss: 7.9546
# Epoch 328, Loss: 7.9142
# Epoch 329, Loss: 7.8840
# Epoch 330, Loss: 7.8621
# Epoch 331, Loss: 7.8350
# Epoch 332, Loss: 7.8047
# Epoch 333, Loss: 7.7796
# Epoch 334, Loss: 7.7828 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 335, Loss: 7.7352
# Epoch 336, Loss: 7.7059
# Epoch 337, Loss: 7.6730
# Epoch 338, Loss: 7.6475
# Epoch 339, Loss: 7.6239
# Epoch 340, Loss: 7.6085
# Epoch 341, Loss: 7.5855
# Epoch 342, Loss: 7.5645
# Epoch 343, Loss: 7.5402
# Epoch 344, Loss: 7.5150
# Epoch 345, Loss: 7.4914
# Epoch 346, Loss: 7.4771
# Epoch 347, Loss: 7.4562
# Epoch 348, Loss: 7.4312
# Epoch 349, Loss: 7.4167
# Epoch 350, Loss: 7.3827
# Epoch 351, Loss: 7.3641
# Epoch 352, Loss: 7.3439
# Epoch 353, Loss: 7.3200
# Epoch 354, Loss: 7.3019
# Epoch 355, Loss: 7.2774
# Epoch 356, Loss: 7.2592
# Epoch 357, Loss: 7.2491
# Epoch 358, Loss: 7.2369
# Epoch 359, Loss: 7.2152
# Epoch 360, Loss: 7.2185 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 361, Loss: 7.1929
# Epoch 362, Loss: 7.1508
# Epoch 363, Loss: 7.1267
# Epoch 364, Loss: 7.1136
# Epoch 365, Loss: 7.0905
# Epoch 366, Loss: 7.0798
# Epoch 367, Loss: 7.0639
# Epoch 368, Loss: 7.0444
# Epoch 369, Loss: 7.0206
# Epoch 370, Loss: 7.0111
# Epoch 371, Loss: 6.9922
# Epoch 372, Loss: 6.9740
# Epoch 373, Loss: 6.9619
# Epoch 374, Loss: 6.9427
# Epoch 375, Loss: 6.9253
# Epoch 376, Loss: 6.9308 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 377, Loss: 6.9012
# Epoch 378, Loss: 6.8805
# Epoch 379, Loss: 6.8625
# Epoch 380, Loss: 6.8494
# Epoch 381, Loss: 6.8367
# Epoch 382, Loss: 6.8306
# Epoch 383, Loss: 6.8240
# Epoch 384, Loss: 6.8048
# Epoch 385, Loss: 6.7992
# Epoch 386, Loss: 6.7847
# Epoch 387, Loss: 6.7605
# Epoch 388, Loss: 6.7449
# Epoch 389, Loss: 6.7236
# Epoch 390, Loss: 6.7054
# Epoch 391, Loss: 6.6831
# Epoch 392, Loss: 6.7080 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 393, Loss: 6.7153 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 394, Loss: 6.6678
# Epoch 395, Loss: 6.6430
# Epoch 396, Loss: 6.6239
# Epoch 397, Loss: 6.6111
# Epoch 398, Loss: 6.6109
# Epoch 399, Loss: 6.6249 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 400, Loss: 6.6036
# Epoch 401, Loss: 6.5563
# Epoch 402, Loss: 6.5482
# Epoch 403, Loss: 6.5476
# Epoch 404, Loss: 6.5348
# Epoch 405, Loss: 6.5132
# Epoch 406, Loss: 6.5034
# Epoch 407, Loss: 6.4949
# Epoch 408, Loss: 6.4768
# Epoch 409, Loss: 6.4653
# Epoch 410, Loss: 6.4470
# Epoch 411, Loss: 6.4556 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 412, Loss: 6.4854 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 413, Loss: 6.4546 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 414, Loss: 6.4298
# Epoch 415, Loss: 6.3997
# Epoch 416, Loss: 6.3899
# Epoch 417, Loss: 6.3750
# Epoch 418, Loss: 6.3680
# Epoch 419, Loss: 6.3691 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 420, Loss: 6.4100 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 421, Loss: 6.3860 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 422, Loss: 6.3404
# Epoch 423, Loss: 6.3181
# Epoch 424, Loss: 6.3061
# Epoch 425, Loss: 6.3028
# Epoch 426, Loss: 6.2878
# Epoch 427, Loss: 6.2883 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 428, Loss: 6.2772
# Epoch 429, Loss: 6.2630
# Epoch 430, Loss: 6.2490
# Epoch 431, Loss: 6.2512 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 432, Loss: 6.2473
# Epoch 433, Loss: 6.2221
# Epoch 434, Loss: 6.2132
# Epoch 435, Loss: 6.2033
# Epoch 436, Loss: 6.1963
# Epoch 437, Loss: 6.1951
# Epoch 438, Loss: 6.1752
# Epoch 439, Loss: 6.1791 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 440, Loss: 6.1747
# Epoch 441, Loss: 6.1609
# Epoch 442, Loss: 6.1551
# Epoch 443, Loss: 6.1318
# Epoch 444, Loss: 6.1282
# Epoch 445, Loss: 6.1312 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 446, Loss: 6.1132
# Epoch 447, Loss: 6.0982
# Epoch 448, Loss: 6.0969
# Epoch 449, Loss: 6.0811
# Epoch 450, Loss: 6.0737
# Epoch 451, Loss: 6.0711
# Epoch 452, Loss: 6.0702
# Epoch 453, Loss: 6.0490
# Epoch 454, Loss: 6.0462
# Epoch 455, Loss: 6.0379
# Epoch 456, Loss: 6.0297
# Epoch 457, Loss: 6.0232
# Epoch 458, Loss: 6.0208
# Epoch 459, Loss: 6.0246 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 460, Loss: 5.9916
# Epoch 461, Loss: 5.9905
# Epoch 462, Loss: 5.9764
# Epoch 463, Loss: 5.9692
# Epoch 464, Loss: 5.9847 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 465, Loss: 5.9560
# Epoch 466, Loss: 5.9530
# Epoch 467, Loss: 5.9421
# Epoch 468, Loss: 5.9327
# Epoch 469, Loss: 5.9317
# Epoch 470, Loss: 5.9216
# Epoch 471, Loss: 5.9231 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 472, Loss: 5.9127
# Epoch 473, Loss: 5.9163 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 474, Loss: 5.9055
# Epoch 475, Loss: 5.8992
# Epoch 476, Loss: 5.8781
# Epoch 477, Loss: 5.8739
# Epoch 478, Loss: 5.8639
# Epoch 479, Loss: 5.8700 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 480, Loss: 5.8525
# Epoch 481, Loss: 5.8414
# Epoch 482, Loss: 5.8394
# Epoch 483, Loss: 5.8425 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 484, Loss: 5.8238
# Epoch 485, Loss: 5.8218
# Epoch 486, Loss: 5.8181
# Epoch 487, Loss: 5.8045
# Epoch 488, Loss: 5.8051 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 489, Loss: 5.8198 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 490, Loss: 5.7950
# Epoch 491, Loss: 5.7979 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 492, Loss: 5.7782
# Epoch 493, Loss: 5.7654
# Epoch 494, Loss: 5.7754 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 495, Loss: 5.7655 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 496, Loss: 5.7880 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 497, Loss: 5.7753 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 498, Loss: 5.7496
# Epoch 499, Loss: 5.7324
# Epoch 500, Loss: 5.7494 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 501, Loss: 5.7421 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 502, Loss: 5.7330 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 503, Loss: 5.7178
# Epoch 504, Loss: 5.7199 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 505, Loss: 5.7184 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 506, Loss: 5.7106
# Epoch 507, Loss: 5.7007
# Epoch 508, Loss: 5.6864
# Epoch 509, Loss: 5.6776
# Epoch 510, Loss: 5.6828 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 511, Loss: 5.6695
# Epoch 512, Loss: 5.6695 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 513, Loss: 5.6655
# Epoch 514, Loss: 5.6540
# Epoch 515, Loss: 5.6455
# Epoch 516, Loss: 5.6467 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 517, Loss: 5.6410
# Epoch 518, Loss: 5.6308
# Epoch 519, Loss: 5.6421 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 520, Loss: 5.6193
# Epoch 521, Loss: 5.6205 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 522, Loss: 5.6173
# Epoch 523, Loss: 5.6045
# Epoch 524, Loss: 5.5941
# Epoch 525, Loss: 5.5939
# Epoch 526, Loss: 5.5896
# Epoch 527, Loss: 5.5879
# Epoch 528, Loss: 5.5936 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 529, Loss: 5.5771
# Epoch 530, Loss: 5.5874 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 531, Loss: 5.5852 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 532, Loss: 5.5693
# Epoch 533, Loss: 5.5582
# Epoch 534, Loss: 5.5760 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 535, Loss: 5.5748 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 536, Loss: 5.5626 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 537, Loss: 5.5656 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 538, Loss: 5.5448
# Epoch 539, Loss: 5.5363
# Epoch 540, Loss: 5.5268
# Epoch 541, Loss: 5.5225
# Epoch 542, Loss: 5.5215
# Epoch 543, Loss: 5.5153
# Epoch 544, Loss: 5.5056
# Epoch 545, Loss: 5.5023
# Epoch 546, Loss: 5.4968
# Epoch 547, Loss: 5.4995 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 548, Loss: 5.4967
# Epoch 549, Loss: 5.4762
# Epoch 550, Loss: 5.4765 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 551, Loss: 5.4723
# Epoch 552, Loss: 5.4609
# Epoch 553, Loss: 5.4792 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 554, Loss: 5.4644 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 555, Loss: 5.4587
# Epoch 556, Loss: 5.4666 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 557, Loss: 5.4480
# Epoch 558, Loss: 5.4720 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 559, Loss: 5.4541 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 560, Loss: 5.4445
# Epoch 561, Loss: 5.4310
# Epoch 562, Loss: 5.4424 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 563, Loss: 5.4468 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 564, Loss: 5.4363 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 565, Loss: 5.4193
# Epoch 566, Loss: 5.4187
# Epoch 567, Loss: 5.4228 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 568, Loss: 5.4133
# Epoch 569, Loss: 5.4027
# Epoch 570, Loss: 5.3986
# Epoch 571, Loss: 5.3922
# Epoch 572, Loss: 5.3830
# Epoch 573, Loss: 5.3791
# Epoch 574, Loss: 5.3834 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 575, Loss: 5.3765
# Epoch 576, Loss: 5.3743
# Epoch 577, Loss: 5.3760 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 578, Loss: 5.3654
# Epoch 579, Loss: 5.3567
# Epoch 580, Loss: 5.3591 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 581, Loss: 5.3657 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 582, Loss: 5.3734 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 583, Loss: 5.3513
# Epoch 584, Loss: 5.3475
# Epoch 585, Loss: 5.3493 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 586, Loss: 5.3431
# Epoch 587, Loss: 5.3368
# Epoch 588, Loss: 5.3359
# Epoch 589, Loss: 5.3207
# Epoch 590, Loss: 5.3250 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 591, Loss: 5.3165
# Epoch 592, Loss: 5.3185 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 593, Loss: 5.3192 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 594, Loss: 5.3127
# Epoch 595, Loss: 5.3121
# Epoch 596, Loss: 5.3006
# Epoch 597, Loss: 5.2976
# Epoch 598, Loss: 5.2915
# Epoch 599, Loss: 5.3018 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 600, Loss: 5.2957 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 601, Loss: 5.2845
# Epoch 602, Loss: 5.2823
# Epoch 603, Loss: 5.2913 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 604, Loss: 5.2772
# Epoch 605, Loss: 5.2849 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 606, Loss: 5.2863 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 607, Loss: 5.2682
# Epoch 608, Loss: 5.2561
# Epoch 609, Loss: 5.2528
# Epoch 610, Loss: 5.2492
# Epoch 611, Loss: 5.2444
# Epoch 612, Loss: 5.2396
# Epoch 613, Loss: 5.2482 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 614, Loss: 5.2366
# Epoch 615, Loss: 5.2455 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 616, Loss: 5.2560 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 617, Loss: 5.2510 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 618, Loss: 5.2298
# Epoch 619, Loss: 5.2172
# Epoch 620, Loss: 5.2132
# Epoch 621, Loss: 5.2178 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 622, Loss: 5.2048
# Epoch 623, Loss: 5.2079 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 624, Loss: 5.2003
# Epoch 625, Loss: 5.1984
# Epoch 626, Loss: 5.2117 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 627, Loss: 5.2072 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 628, Loss: 5.2454 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 629, Loss: 5.2035 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 630, Loss: 5.1817
# Epoch 631, Loss: 5.1832 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 632, Loss: 5.1878 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 633, Loss: 5.2027 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 634, Loss: 5.1952 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 635, Loss: 5.1651
# Epoch 636, Loss: 5.1706 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 637, Loss: 5.1643
# Epoch 638, Loss: 5.1593
# Epoch 639, Loss: 5.1752 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 640, Loss: 5.1526
# Epoch 641, Loss: 5.1548 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 642, Loss: 5.1470
# Epoch 643, Loss: 5.1663 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 644, Loss: 5.1573 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 645, Loss: 5.1563 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 646, Loss: 5.1476 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 647, Loss: 5.1784 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 648, Loss: 5.1410
# Epoch 649, Loss: 5.1410 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 650, Loss: 5.1460 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 651, Loss: 5.1318
# Epoch 652, Loss: 5.1292
# Epoch 653, Loss: 5.1345 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 654, Loss: 5.1483 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 655, Loss: 5.1280
# Epoch 656, Loss: 5.1191
# Epoch 657, Loss: 5.1278 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 658, Loss: 5.1291 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 659, Loss: 5.1311 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 660, Loss: 5.1306 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 661, Loss: 5.1020
# Epoch 662, Loss: 5.1214 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 663, Loss: 5.1069 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 664, Loss: 5.0892
# Epoch 665, Loss: 5.0860
# Epoch 666, Loss: 5.0900 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 667, Loss: 5.1010 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 668, Loss: 5.0988 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 669, Loss: 5.0996 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 670, Loss: 5.0920 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 671, Loss: 5.0852
# Epoch 672, Loss: 5.0849
# Epoch 673, Loss: 5.0718
# Epoch 674, Loss: 5.0703
# Epoch 675, Loss: 5.0647
# Epoch 676, Loss: 5.0588
# Epoch 677, Loss: 5.0763 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 678, Loss: 5.0885 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 679, Loss: 5.0794 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 680, Loss: 5.0569
# Epoch 681, Loss: 5.0578 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 682, Loss: 5.0479
# Epoch 683, Loss: 5.0616 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 684, Loss: 5.0471
# Epoch 685, Loss: 5.0553 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 686, Loss: 5.0494 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 687, Loss: 5.0365
# Epoch 688, Loss: 5.0410 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 689, Loss: 5.0373 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 690, Loss: 5.0448 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 691, Loss: 5.0430 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 692, Loss: 5.0781 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 693, Loss: 5.0272
# Epoch 694, Loss: 5.0270
# Epoch 695, Loss: 5.0232
# Epoch 696, Loss: 5.0190
# Epoch 697, Loss: 5.0071
# Epoch 698, Loss: 5.0032
# Epoch 699, Loss: 5.0135 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 700, Loss: 5.0535 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 701, Loss: 5.0336 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 702, Loss: 5.0057 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 703, Loss: 4.9922
# Epoch 704, Loss: 4.9917
# Epoch 705, Loss: 4.9895
# Epoch 706, Loss: 5.0006 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 707, Loss: 5.0058 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 708, Loss: 5.0024 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 709, Loss: 4.9897 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 710, Loss: 4.9797
# Epoch 711, Loss: 4.9794
# Epoch 712, Loss: 4.9804 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 713, Loss: 4.9760
# Epoch 714, Loss: 4.9812 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 715, Loss: 4.9725
# Epoch 716, Loss: 4.9811 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 717, Loss: 4.9650
# Epoch 718, Loss: 4.9612
# Epoch 719, Loss: 4.9610
# Epoch 720, Loss: 4.9607
# Epoch 721, Loss: 4.9563
# Epoch 722, Loss: 4.9584 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 723, Loss: 4.9557
# Epoch 724, Loss: 4.9538
# Epoch 725, Loss: 4.9519
# Epoch 726, Loss: 4.9674 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 727, Loss: 4.9596 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 728, Loss: 4.9543 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 729, Loss: 4.9518
# Epoch 730, Loss: 4.9524 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 731, Loss: 4.9424
# Epoch 732, Loss: 4.9493 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 733, Loss: 4.9359
# Epoch 734, Loss: 4.9285
# Epoch 735, Loss: 4.9430 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 736, Loss: 4.9234
# Epoch 737, Loss: 4.9213
# Epoch 738, Loss: 4.9094
# Epoch 739, Loss: 4.9075
# Epoch 740, Loss: 4.9070
# Epoch 741, Loss: 4.9076 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 742, Loss: 4.9058
# Epoch 743, Loss: 4.9151 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 744, Loss: 4.9082 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 745, Loss: 4.9077 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 746, Loss: 4.8995
# Epoch 747, Loss: 4.9147 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 748, Loss: 4.8930
# Epoch 749, Loss: 4.8976 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 750, Loss: 4.8877
# Epoch 751, Loss: 4.8991 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 752, Loss: 4.8974 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 753, Loss: 4.8824
# Epoch 754, Loss: 4.8773
# Epoch 755, Loss: 4.8795 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 756, Loss: 4.8940 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 757, Loss: 4.8832 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 758, Loss: 4.8901 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 759, Loss: 4.9068 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 760, Loss: 4.9124 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 761, Loss: 4.8982 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 762, Loss: 4.9193 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 763, Loss: 4.8824 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 764, Loss: 4.8629
# Epoch 765, Loss: 4.8621
# Epoch 766, Loss: 4.8577
# Epoch 767, Loss: 4.8546
# Epoch 768, Loss: 4.8567 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 769, Loss: 4.8497
# Epoch 770, Loss: 4.8503 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 771, Loss: 4.8485
# Epoch 772, Loss: 4.8442
# Epoch 773, Loss: 4.8727 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 774, Loss: 4.8913 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 775, Loss: 4.8499 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 776, Loss: 4.8548 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 777, Loss: 4.8528 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 778, Loss: 4.8428
# Epoch 779, Loss: 4.8376
# Epoch 780, Loss: 4.8362
# Epoch 781, Loss: 4.8203
# Epoch 782, Loss: 4.8555 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 783, Loss: 4.8386 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 784, Loss: 4.8456 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 785, Loss: 4.8431 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 786, Loss: 4.8383 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 787, Loss: 4.8231 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 788, Loss: 4.8138
# Epoch 789, Loss: 4.8158 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 790, Loss: 4.8144 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 791, Loss: 4.8280 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 792, Loss: 4.8395 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 793, Loss: 4.8296 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 794, Loss: 4.8262 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 795, Loss: 4.8126
# Epoch 796, Loss: 4.8150 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 797, Loss: 4.8164 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 798, Loss: 4.8374 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 799, Loss: 4.8046
# Epoch 800, Loss: 4.8019
# Epoch 801, Loss: 4.8166 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 802, Loss: 4.8341 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 803, Loss: 4.8182 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 804, Loss: 4.7997
# Epoch 805, Loss: 4.8054 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 806, Loss: 4.8025 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 807, Loss: 4.7932
# Epoch 808, Loss: 4.7842
# Epoch 809, Loss: 4.7753
# Epoch 810, Loss: 4.7850 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 811, Loss: 4.7872 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 812, Loss: 4.8114 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 813, Loss: 4.7868 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 814, Loss: 4.7683
# Epoch 815, Loss: 4.7744 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 816, Loss: 4.7660
# Epoch 817, Loss: 4.7656
# Epoch 818, Loss: 4.7655 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 819, Loss: 4.7809 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 820, Loss: 4.7783 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 821, Loss: 4.8002 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 822, Loss: 4.7777 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 823, Loss: 4.7756 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 824, Loss: 4.7848 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 825, Loss: 4.7918 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 826, Loss: 4.7895 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 827, Loss: 4.7752 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 828, Loss: 4.7562
# Epoch 829, Loss: 4.7595 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 830, Loss: 4.7546
# Epoch 831, Loss: 4.7419
# Epoch 832, Loss: 4.7465 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 833, Loss: 4.7425 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 834, Loss: 4.7381
# Epoch 835, Loss: 4.7404 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 836, Loss: 4.7560 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 837, Loss: 4.7604 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 838, Loss: 4.7513 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 839, Loss: 4.7578 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 840, Loss: 4.7505 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 841, Loss: 4.7512 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 842, Loss: 4.7437 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 843, Loss: 4.7399 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 844, Loss: 4.7500 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 845, Loss: 4.7285
# Epoch 846, Loss: 4.7285 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 847, Loss: 4.7354 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 848, Loss: 4.7334 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 849, Loss: 4.7357 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 850, Loss: 4.7544 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 851, Loss: 4.7403 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 852, Loss: 4.7212
# Epoch 853, Loss: 4.7475 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 854, Loss: 4.7384 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 855, Loss: 4.7376 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 856, Loss: 4.7335 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 857, Loss: 4.7058
# Epoch 858, Loss: 4.7168 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 859, Loss: 4.7129 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 860, Loss: 4.6967
# Epoch 861, Loss: 4.7032 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 862, Loss: 4.6993 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 863, Loss: 4.7042 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 864, Loss: 4.7134 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 865, Loss: 4.7051 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 866, Loss: 4.6971 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 867, Loss: 4.6987 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 868, Loss: 4.7279 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 869, Loss: 4.7010 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 870, Loss: 4.7018 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 871, Loss: 4.7175 EarlyStopping: 11/20 epoch óta nincs javulás.
# Epoch 872, Loss: 4.7127 EarlyStopping: 12/20 epoch óta nincs javulás.
# Epoch 873, Loss: 4.6875
# Epoch 874, Loss: 4.6807
# Epoch 875, Loss: 4.6823 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 876, Loss: 4.6841 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 877, Loss: 4.6792
# Epoch 878, Loss: 4.6745
# Epoch 879, Loss: 4.6652
# Epoch 880, Loss: 4.6698 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 881, Loss: 4.6659 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 882, Loss: 4.6694 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 883, Loss: 4.6784 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 884, Loss: 4.6678 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 885, Loss: 4.6753 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 886, Loss: 4.6734 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 887, Loss: 4.6766 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 888, Loss: 4.6801 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 889, Loss: 4.7147 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 890, Loss: 4.7156 EarlyStopping: 11/20 epoch óta nincs javulás.
# Epoch 891, Loss: 4.6815 EarlyStopping: 12/20 epoch óta nincs javulás.
# Epoch 892, Loss: 4.6913 EarlyStopping: 13/20 epoch óta nincs javulás.
# Epoch 893, Loss: 4.6757 EarlyStopping: 14/20 epoch óta nincs javulás.
# Epoch 894, Loss: 4.6881 EarlyStopping: 15/20 epoch óta nincs javulás.
# Epoch 895, Loss: 4.6776 EarlyStopping: 16/20 epoch óta nincs javulás.
# Epoch 896, Loss: 4.6749 EarlyStopping: 17/20 epoch óta nincs javulás.
# Epoch 897, Loss: 4.6719 EarlyStopping: 18/20 epoch óta nincs javulás.
# Epoch 898, Loss: 4.6532
# Epoch 899, Loss: 4.6504
# Epoch 900, Loss: 4.6582 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 901, Loss: 4.6510 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 902, Loss: 4.6468
# Epoch 903, Loss: 4.6526 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 904, Loss: 4.6412
# Epoch 905, Loss: 4.6417 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 906, Loss: 4.6371
# Epoch 907, Loss: 4.6494 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 908, Loss: 4.6616 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 909, Loss: 4.6428 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 910, Loss: 4.6298
# Epoch 911, Loss: 4.6340 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 912, Loss: 4.6295
# Epoch 913, Loss: 4.6263
# Epoch 914, Loss: 4.6247
# Epoch 915, Loss: 4.6357 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 916, Loss: 4.6186
# Epoch 917, Loss: 4.6535 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 918, Loss: 4.6489 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 919, Loss: 4.6202 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 920, Loss: 4.6550 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 921, Loss: 4.6294 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 922, Loss: 4.6209 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 923, Loss: 4.6293 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 924, Loss: 4.6426 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 925, Loss: 4.6382 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 926, Loss: 4.6420 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 927, Loss: 4.6183
# Epoch 928, Loss: 4.6162
# Epoch 929, Loss: 4.6154
# Epoch 930, Loss: 4.6043
# Epoch 931, Loss: 4.6228 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 932, Loss: 4.6308 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 933, Loss: 4.6331 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 934, Loss: 4.6134 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 935, Loss: 4.6075 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 936, Loss: 4.5996
# Epoch 937, Loss: 4.6033 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 938, Loss: 4.6198 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 939, Loss: 4.6239 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 940, Loss: 4.6394 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 941, Loss: 4.6192 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 942, Loss: 4.5975
# Epoch 943, Loss: 4.5874
# Epoch 944, Loss: 4.5868
# Epoch 945, Loss: 4.5850
# Epoch 946, Loss: 4.6353 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 947, Loss: 4.6466 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 948, Loss: 4.6179 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 949, Loss: 4.5935 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 950, Loss: 4.5915 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 951, Loss: 4.5837
# Epoch 952, Loss: 4.5969 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 953, Loss: 4.6213 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 954, Loss: 4.6149 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 955, Loss: 4.5854 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 956, Loss: 4.5845 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 957, Loss: 4.5934 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 958, Loss: 4.6221 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 959, Loss: 4.6346 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 960, Loss: 4.6080 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 961, Loss: 4.5981 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 962, Loss: 4.6217 EarlyStopping: 11/20 epoch óta nincs javulás.
# Epoch 963, Loss: 4.5749
# Epoch 964, Loss: 4.5863 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 965, Loss: 4.5740
# Epoch 966, Loss: 4.5635
# Epoch 967, Loss: 4.5685 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 968, Loss: 4.5726 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 969, Loss: 4.5703 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 970, Loss: 4.5612
# Epoch 971, Loss: 4.5593
# Epoch 972, Loss: 4.5544
# Epoch 973, Loss: 4.5561 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 974, Loss: 4.5604 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 975, Loss: 4.5923 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 976, Loss: 4.5639 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 977, Loss: 4.5580 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 978, Loss: 4.5752 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 979, Loss: 4.5535
# Epoch 980, Loss: 4.5612 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 981, Loss: 4.5587 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 982, Loss: 4.5469
# Epoch 983, Loss: 4.5587 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 984, Loss: 4.5475 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 985, Loss: 4.5436
# Epoch 986, Loss: 4.5493 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 987, Loss: 4.5470 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 988, Loss: 4.5458 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 989, Loss: 4.5417
# Epoch 990, Loss: 4.5604 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 991, Loss: 4.5348
# Epoch 992, Loss: 4.5403 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 993, Loss: 4.5367 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 994, Loss: 4.5740 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 995, Loss: 4.5618 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 996, Loss: 4.5493 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 997, Loss: 4.5461 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 998, Loss: 4.5370 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 999, Loss: 4.5487 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 1000, Loss: 4.5316
# Epoch 1001, Loss: 4.5247
# Epoch 1002, Loss: 4.5359 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1003, Loss: 4.5256 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1004, Loss: 4.5323 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1005, Loss: 4.5233
# Epoch 1006, Loss: 4.5459 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1007, Loss: 4.5449 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1008, Loss: 4.5312 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1009, Loss: 4.5226
# Epoch 1010, Loss: 4.5215
# Epoch 1011, Loss: 4.5222 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1012, Loss: 4.5225 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1013, Loss: 4.5139
# Epoch 1014, Loss: 4.5205 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1015, Loss: 4.5245 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1016, Loss: 4.5334 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1017, Loss: 4.5203 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1018, Loss: 4.5235 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 1019, Loss: 4.5183 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 1020, Loss: 4.5165 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 1021, Loss: 4.5259 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 1022, Loss: 4.5432 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 1023, Loss: 4.5267 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 1024, Loss: 4.5187 EarlyStopping: 11/20 epoch óta nincs javulás.
# Epoch 1025, Loss: 4.5212 EarlyStopping: 12/20 epoch óta nincs javulás.
# Epoch 1026, Loss: 4.5132
# Epoch 1027, Loss: 4.5164 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1028, Loss: 4.5141 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1029, Loss: 4.5048
# Epoch 1030, Loss: 4.5031
# Epoch 1031, Loss: 4.5101 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1032, Loss: 4.5296 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1033, Loss: 4.5124 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1034, Loss: 4.4911
# Epoch 1035, Loss: 4.4929 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1036, Loss: 4.4951 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1037, Loss: 4.4959 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1038, Loss: 4.4924 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1039, Loss: 4.4895
# Epoch 1040, Loss: 4.4870
# Epoch 1041, Loss: 4.4909 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1042, Loss: 4.4906 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1043, Loss: 4.4925 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1044, Loss: 4.4972 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1045, Loss: 4.5125 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 1046, Loss: 4.4901 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 1047, Loss: 4.4844
# Epoch 1048, Loss: 4.4833
# Epoch 1049, Loss: 4.4907 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1050, Loss: 4.5017 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1051, Loss: 4.4808
# Epoch 1052, Loss: 4.4900 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1053, Loss: 4.5020 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1054, Loss: 4.5203 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1055, Loss: 4.5179 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1056, Loss: 4.4885 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 1057, Loss: 4.4979 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 1058, Loss: 4.5009 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 1059, Loss: 4.4880 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 1060, Loss: 4.4783
# Epoch 1061, Loss: 4.4882 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1062, Loss: 4.5046 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1063, Loss: 4.4882 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1064, Loss: 4.4715
# Epoch 1065, Loss: 4.4679
# Epoch 1066, Loss: 4.4710 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1067, Loss: 4.4743 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1068, Loss: 4.4822 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1069, Loss: 4.5038 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1070, Loss: 4.5214 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 1071, Loss: 4.4838 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 1072, Loss: 4.5070 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 1073, Loss: 4.4724 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 1074, Loss: 4.4648
# Epoch 1075, Loss: 4.4649 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1076, Loss: 4.4962 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1077, Loss: 4.5010 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1078, Loss: 4.4786 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1079, Loss: 4.4773 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 1080, Loss: 4.4876 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 1081, Loss: 4.4863 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 1082, Loss: 4.4683 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 1083, Loss: 4.4560
# Epoch 1084, Loss: 4.4572 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1085, Loss: 4.4540
# Epoch 1086, Loss: 4.4558 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1087, Loss: 4.4991 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1088, Loss: 4.4750 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1089, Loss: 4.4510
# Epoch 1090, Loss: 4.4805 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1091, Loss: 4.4522 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1092, Loss: 4.4471
# Epoch 1093, Loss: 4.4447
# Epoch 1094, Loss: 4.4569 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1095, Loss: 4.4407
# Epoch 1096, Loss: 4.4398
# Epoch 1097, Loss: 4.4414 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1098, Loss: 4.4286
# Epoch 1099, Loss: 4.4362 EarlyStopping: 1/20 epoch óta nincs javulás.
# Epoch 1100, Loss: 4.4362 EarlyStopping: 2/20 epoch óta nincs javulás.
# Epoch 1101, Loss: 4.4324 EarlyStopping: 3/20 epoch óta nincs javulás.
# Epoch 1102, Loss: 4.4332 EarlyStopping: 4/20 epoch óta nincs javulás.
# Epoch 1103, Loss: 4.4382 EarlyStopping: 5/20 epoch óta nincs javulás.
# Epoch 1104, Loss: 4.4450 EarlyStopping: 6/20 epoch óta nincs javulás.
# Epoch 1105, Loss: 4.4391 EarlyStopping: 7/20 epoch óta nincs javulás.
# Epoch 1106, Loss: 4.4376 EarlyStopping: 8/20 epoch óta nincs javulás.
# Epoch 1107, Loss: 4.4395 EarlyStopping: 9/20 epoch óta nincs javulás.
# Epoch 1108, Loss: 4.4310 EarlyStopping: 10/20 epoch óta nincs javulás.
# Epoch 1109, Loss: 4.4308 EarlyStopping: 11/20 epoch óta nincs javulás.
# Epoch 1110, Loss: 4.4438 EarlyStopping: 12/20 epoch óta nincs javulás.
# Epoch 1111, Loss: 4.4411 EarlyStopping: 13/20 epoch óta nincs javulás.
# Epoch 1112, Loss: 4.4289 EarlyStopping: 14/20 epoch óta nincs javulás.
# Epoch 1113, Loss: 4.4505 EarlyStopping: 15/20 epoch óta nincs javulás.
# Epoch 1114, Loss: 4.4439 EarlyStopping: 16/20 epoch óta nincs javulás.
# Epoch 1115, Loss: 4.4426 EarlyStopping: 17/20 epoch óta nincs javulás.
# Epoch 1116, Loss: 4.4377 EarlyStopping: 18/20 epoch óta nincs javulás.
# Epoch 1117, Loss: 4.4478 EarlyStopping: 19/20 epoch óta nincs javulás.
# Epoch 1118, Loss: 4.4394 EarlyStopping: 20/20 epoch óta nincs javulás. Korai leállítás aktiválva.

# %%
fname_suffix = f"H{HIDDEN_SIZE}_L{NUM_LAYERS}_LR{LEARNING_RATE}_BS{BATCH_SIZE}_S{N_STEPS}_PAT{EARLY_STOPPING_PATIENCE}"

os.makedirs("logs", exist_ok=True)
os.makedirs("plots", exist_ok=True)

csv_path = os.path.join("logs", f"train_loss_{fname_suffix}.csv")
png_path = os.path.join("plots", f"train_loss_{fname_suffix}.png")

# %%
pd.DataFrame({
    "epoch": list(range(1, len(train_loss_history) + 1)),
    "train_loss": train_loss_history
}).to_csv(csv_path, index=False)

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_loss_history, label="Train loss")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Tanulási görbe")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(png_path)
plt.show()

# %%
MODEL_DIR = "models"
os.makedirs(MODEL_DIR, exist_ok=True)

model_path = os.path.join(MODEL_DIR, f"model_{fname_suffix}.pt")
torch.save(model.state_dict(), model_path)

print(f"Modell mentve: {model_path}")
# Out:
# Modell mentve: models/model_H16_L1_LR0.001_BS1024_S7_PAT20.pt

# %%
model.eval()
predictions = []
actuals = []

with torch.no_grad():
    for inputs, targets in test_loader:
        inputs = inputs.to(device)
        outputs = model(inputs).cpu().numpy()
        predictions.extend(outputs.flatten())
        actuals.extend(targets.numpy().flatten())

from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(actuals, predictions)
mae = mean_absolute_error(actuals, predictions)

print(f"Teszt MSE: {mse:.3f}")
print(f"Teszt MAE: {mae:.3f}")
# Out:
# Teszt MSE: 7.521
# Teszt MAE: 2.097

# %%
log_file = "training_log.csv"
log_columns = [
    "training", "hidden_size", "learning_rate","layers", "epochs", "batch_size",
    "train_loss", "test_mse", "test_mae", "elapsed_time"
]

if not os.path.exists(log_file):
    pd.DataFrame(columns=log_columns).to_csv(log_file, index=False)

log_entry = {
    "training": csv_path,
    "hidden_size": HIDDEN_SIZE,
    "learning_rate": LEARNING_RATE,
    "layers" : NUM_LAYERS,
    "epochs" : epoch + 1,
    "batch_size": BATCH_SIZE,
    "train_loss": train_loss,
    "test_mse": mse,
    "test_mae": mae,
    "elapsed_time": round(elapsed_time, 2)
}

log_df = pd.read_csv(log_file)
log_df = pd.concat([log_df, pd.DataFrame([log_entry])], ignore_index=True)
log_df.to_csv(log_file, index=False)
# Out:
# FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
